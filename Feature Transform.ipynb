# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\sultan chowdhury\\OneDrive\\Desktop\\supershops.csv")

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df2=df.copy()
df3=df.copy()
df4=df.copy()
df5=df.copy()
df6=df.copy()
df7=df.copy()

# %% [markdown]
# # Normalaization

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
df2['Marketing Spend']=m.fit_transform(df2[['Marketing Spend']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
m_res=m.fit(df2[['Administration']])
df2['Administration']=m.transform(df2[['Administration']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744  471784.10    Dhaka  192261.83
# 1         0.983359        0.761972  443898.53      Ctg  191792.06
# 2         0.927985        0.379579  407934.54  Rangpur  191050.39
# 3         0.873136        0.512998  383199.62    Dhaka  182901.99
# 4         0.859438        0.305328  366168.42  Rangpur  166187.94

# %%
m=MinMaxScaler()

# %%
 m.fit(df2[['Transport']])
# Out:
# MinMaxScaler()

# %%
df2['Transport']=m.fit_transform(df2[['Transport']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744   1.000000    Dhaka  192261.83
# 1         0.983359        0.761972   0.940893      Ctg  191792.06
# 2         0.927985        0.379579   0.864664  Rangpur  191050.39
# 3         0.873136        0.512998   0.812235    Dhaka  182901.99
# 4         0.859438        0.305328   0.776136  Rangpur  166187.94

# %%
for col in df2.columns:
    if df2[col].dtype!='object'and col!='Profit':
        df2[col]=m.fit_transform(df2[[col]])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744   1.000000    Dhaka  192261.83
# 1         0.983359        0.761972   0.940893      Ctg  191792.06
# 2         0.927985        0.379579   0.864664  Rangpur  191050.39
# 3         0.873136        0.512998   0.812235    Dhaka  182901.99
# 4         0.859438        0.305328   0.776136  Rangpur  166187.94

# %% [markdown]
# # standardization

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
df4['Marketing Spend']=st.fit_transform(df4[['Marketing Spend']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
df4['Administration']=st.fit_transform(df4[['Administration']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753  471784.10    Dhaka  192261.83
# 1         1.955860        1.082807  443898.53      Ctg  191792.06
# 2         1.754364       -0.728257  407934.54  Rangpur  191050.39
# 3         1.554784       -0.096365  383199.62    Dhaka  182901.99
# 4         1.504937       -1.079919  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
df4['Transport']=st.fit_transform(df4[['Transport']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753   2.165287    Dhaka  192261.83
# 1         1.955860        1.082807   1.929843      Ctg  191792.06
# 2         1.754364       -0.728257   1.626191  Rangpur  191050.39
# 3         1.554784       -0.096365   1.417348    Dhaka  182901.99
# 4         1.504937       -1.079919   1.273550  Rangpur  166187.94

# %%
for column in df4.columns:
    if df4[column].dtype!='object'and column!='Profit':
        df4[column]=st.fit_transform(df4[[column]])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753   2.165287    Dhaka  192261.83
# 1         1.955860        1.082807   1.929843      Ctg  191792.06
# 2         1.754364       -0.728257   1.626191  Rangpur  191050.39
# 3         1.554784       -0.096365   1.417348    Dhaka  182901.99
# 4         1.504937       -1.079919   1.273550  Rangpur  166187.94

# %% [markdown]
# # Log Transform

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
log=FunctionTransformer(np.log1p)

# %%
df3['Transport']=log.fit_transform(df5[['Transport']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  13.064279    Dhaka  192261.83
# 1        162597.70       151377.59  13.003354      Ctg  191792.06
# 2        153441.51       101145.55  12.918864  Rangpur  191050.39
# 3        144372.41       118671.85  12.856314    Dhaka  182901.99
# 4        142107.34        91391.77  12.810851  Rangpur  166187.94

# %%
df3['Marketing Spend']=log.fit_transform(df3[['Marketing Spend']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        11.648545       136897.80  13.064279    Dhaka  192261.83
# 1        11.999040       151377.59  13.003354      Ctg  191792.06
# 2        11.941081       101145.55  12.918864  Rangpur  191050.39
# 3        11.880158       118671.85  12.856314    Dhaka  182901.99
# 4        11.864345        91391.77  12.810851  Rangpur  166187.94

# %%
df3['Administration']=log.fit_transform(df3[['Administration']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        11.648545       11.826997  13.064279    Dhaka  192261.83
# 1        11.999040       11.927539  13.003354      Ctg  191792.06
# 2        11.941081       11.524326  12.918864  Rangpur  191050.39
# 3        11.880158       11.684126  12.856314    Dhaka  182901.99
# 4        11.864345       11.422922  12.810851  Rangpur  166187.94

# %%
for i in df6.columns:
    if df6[i].dtype!='object' and i!='Profit':
        df6[i]=log.fit_transform(df6[[i]])

# %%
df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        11.648545       11.826997  13.064279    Dhaka  192261.83
# 1        11.999040       11.927539  13.003354      Ctg  191792.06
# 2        11.941081       11.524326  12.918864  Rangpur  191050.39
# 3        11.880158       11.684126  12.856314    Dhaka  182901.99
# 4        11.864345       11.422922  12.810851  Rangpur  166187.94

# %% [markdown]
# # Max Absolute scaler

# %%
from sklearn.preprocessing import MaxAbsScaler
max_sc=MaxAbsScaler()

# %%
max_sc.fit(df5[['Marketing Spend']])
# Out:
# MaxAbsScaler()

# %%
df5['Marketing Spend']=max_sc.fit_transform(df5[['Marketing Spend']])

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
df5['Administration']=max_sc.fit_transform(df5[['Administration']])

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527  471784.10    Dhaka  192261.83
# 1         0.983359        0.828805  443898.53      Ctg  191792.06
# 2         0.927985        0.553781  407934.54  Rangpur  191050.39
# 3         0.873136        0.649738  383199.62    Dhaka  182901.99
# 4         0.859438        0.500378  366168.42  Rangpur  166187.94

# %%
df5['Transport']=max_sc.fit_transform(df5[['Transport']])

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527   1.000000    Dhaka  192261.83
# 1         0.983359        0.828805   0.940893      Ctg  191792.06
# 2         0.927985        0.553781   0.864664  Rangpur  191050.39
# 3         0.873136        0.649738   0.812235    Dhaka  182901.99
# 4         0.859438        0.500378   0.776136  Rangpur  166187.94

# %%
for col in df7.columns:
    if df7[col].dtype!='object' and col!='Profit':
        df7[col]=max_sc.fit_transform(df7[[col]])

# %%
df7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527   1.000000    Dhaka  192261.83
# 1         0.983359        0.828805   0.940893      Ctg  191792.06
# 2         0.927985        0.553781   0.864664  Rangpur  191050.39
# 3         0.873136        0.649738   0.812235    Dhaka  182901.99
# 4         0.859438        0.500378   0.776136  Rangpur  166187.94

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
ros=RobustScaler()

# %%
df8=df.copy()

# %%
df8['Marketing Spend']=ros.fit_transform(df8[['Marketing Spend']])
df8.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94

# %%
df8['Administration']=ros.fit_transform(df8[['Administration']])

# %%
df8.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.345355  471784.10    Dhaka  192261.83
# 1         1.452113        0.697565  443898.53      Ctg  191792.06
# 2         1.303634       -0.524290  407934.54  Rangpur  191050.39
# 3         1.156567       -0.097977  383199.62    Dhaka  182901.99
# 4         1.119836       -0.761543  366168.42  Rangpur  166187.94

# %%
df8['Transport']=ros.fit_transform(df8[['Transport']])

# %%
df8.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.345355   1.552016    Dhaka  192261.83
# 1         1.452113        0.697565   1.383714      Ctg  191792.06
# 2         1.303634       -0.524290   1.166654  Rangpur  191050.39
# 3         1.156567       -0.097977   1.017368    Dhaka  182901.99
# 4         1.119836       -0.761543   0.914576  Rangpur  166187.94

# %%
df9=df.copy()

# %%
for i in df9.columns:
    if df9[i].dtype!='object' and i!='Profit':
        df9[i]=ros.fit_transform(df9[[i]])

# %%
df9.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.345355   1.552016    Dhaka  192261.83
# 1         1.452113        0.697565   1.383714      Ctg  191792.06
# 2         1.303634       -0.524290   1.166654  Rangpur  191050.39
# 3         1.156567       -0.097977   1.017368    Dhaka  182901.99
# 4         1.119836       -0.761543   0.914576  Rangpur  166187.94
